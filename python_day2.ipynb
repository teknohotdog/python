# %% [markdown]
# # Markdown은 코드가 아닌 글을 쓰는 곳입니다.
# ## Run을 하면 디자인이 입혀짐. HTML화?
# #### 3단걔

# %% [markdown]
# ### 제목 heading

# %%
a = [1,2,3,4,5]

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# insert image![IMG_0398.JPG](attachment:IMG_0398.JPG)

# %% [markdown]
# $e^{i\pi} + 1 = 0$
#
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$
#
# | This | is   |
# |------|------|
# |   a  | table|
#
# print "Hello World"
#
# <img src="../images/python_logo.svg" />
#
# <video controls src="../images/animation.m4v" />

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/hhVCdxtofWU" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
a.append(6)

# %%
## shift + tab 설명나옴

# %%
a?

# %%
# while 반복 횟수를 미리 알 수 없을 때 사용.
#무한 반목이 되지 않도록 주의

x = 10000
i = 1

while (2**i < x):
    i = 2**i

# %%
# dictionary {키:값, 키:값... }
b = {'age':20, 'city':'seoul'}

# %%
b['age']

print(b)
# Out:
# {'age': 20, 'city': 'seoul'}

# %%
# 키와 값을 추가
b  ['part']=['개발부']

# %%
b
# Out:
# {'age': 20, 'city': 'seoul', 'part': ['개발부']}
